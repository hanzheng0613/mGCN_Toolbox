# %%
import numpy as np
np.random.seed(0)
import torch
torch.autograd.set_detect_anomaly(True)
torch.manual_seed(0)
torch.cuda.manual_seed_all(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
import argparse
from mGCN_Toolbox.utils.process import *
import scipy.io as sio

def parse_args():
    # input arguments
    parser = argparse.ArgumentParser(description='DMGI')

    parser.add_argument('--embedder', nargs='?', default='DGI')
    parser.add_argument('--dataset', nargs='?', default='acm')
    #parser.add_argument('--metapaths', nargs='?', default='PLP,PAP')

    parser.add_argument('--nb_epochs', type=int, default=10)
    parser.add_argument('--hid_units', type=int, default=64)
    
    parser.add_argument('--training_ratio', type=float, default=0.3,
                        help='Training Ratio')
    parser.add_argument('--validing_ratio', type=float, default=0.1,
                        help='Validing Ratio')
    parser.add_argument('--lr', type = float, default = 0.001)
    parser.add_argument('--l2_coef', type=float, default=0.0001)
    parser.add_argument('--drop_prob', type=float, default=0.5)
    parser.add_argument('--reg_coef', type=float, default=0.001)
    parser.add_argument('--sup_coef', type=float, default=0.1)
    parser.add_argument('--sc', type=float, default=3.0, help='GCN self connection')
    parser.add_argument('--margin', type=float, default=0.1)
    parser.add_argument('--gpu_num', type=int, default=0)
    parser.add_argument('--patience', type=int, default=20)
    parser.add_argument('--nheads', type=int, default=1)
    parser.add_argument('--activation', nargs='?', default='relu')
    parser.add_argument('--isSemi', action='store_true', default=False)
    parser.add_argument('--isBias', action='store_true', default=False)
    parser.add_argument('--isAttn', action='store_true', default=False)
    parser.add_argument('--test_view', type=int, default=0, help='the id of gpu to use')
    return parser.parse_known_args()

def printConfig(args):
    args_names = []
    args_vals = []
    for arg in vars(args):
        args_names.append(arg)
        args_vals.append(getattr(args, arg))
    print(args_names)
    print(args_vals)

def main():
    args, unknown = parse_args()

    if args.embedder == 'DMGI':
        from mGCN_Toolbox.model.DMGI.DMGI_link import DMGI
        embedder = DMGI(args)
    elif args.embedder == 'DGI':
        from mGCN_Toolbox.model.DMGI.DGI_link import DGI
        embedder = DGI(args)

    #embedder.training()
    
    AUC, ap, hits = embedder.training()
    print("Average-percision:", np.mean(ap), np.std(ap))
    print("Average-AUC:", np.mean(AUC), np.std(AUC))
    
    return AUC, hits, ap

if __name__ == '__main__':
    args, unknown = parse_args()
    print(args.dataset)
    print(args.embedder)
    
    AUC, hits, ap = main()
# Out:
# acm
# DGI
# initial  torch.Size([1, 3025, 64])
# reshape embeds: torch.Size([3025, 64])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.5016883435040936
# Best Test: 0.502008450501971
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.573385948600025
# Best Test: 0.5728714141654299
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.6061394948123331
# Best Test: 0.6056448618734608
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.6109396605673225
# Best Test: 0.6106328312080832
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.6135123134992404
# Best Test: 0.6132861276080647
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.6173908837947639
# Best Test: 0.6171487965934344
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.6201448106069064
# Best Test: 0.6198379535541343
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.6212641686911057
# Best Test: 0.6208582840512539
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.6221022604425569
# Best Test: 0.6215835032828676
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.6231466129443514
# Best Test: 0.6225295865297611
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.6241075485398984
# Best Test: 0.6234447177430392
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# <class 'torch.Tensor'>
# Epoch: 0
# Best Validation: 0.6244700483492069
# Best Test: 0.6238093291635988
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ret torch.Size([3025, 2])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 77
#      74 print(args.dataset)
#      75 print(args.embedder)
# ---> 77 AUC, hits, ap = main()
#
# Cell In[1], line 66, in main()
#      62     embedder = DGI(args)
#      64 #embedder.training()
# ---> 66 AUC, ap, hits = embedder.training()
#      67 print("Average-percision:", np.mean(ap), np.std(ap))
#      68 print("Average-AUC:", np.mean(AUC), np.std(AUC))
#
# File ~/Desktop/mGCN_Toolbox 0609/mGCN_Toolbox/model/DMGI/DGI_link.py:76, in DGI.training(self)
#      72 embeds = torch.mean(torch.cat(final_embeds), 0).unsqueeze(0)
#      73 #print("- Integrated")
#      74 #evaluate(embeds, self.idx_train, self.idx_val, self.idx_test, self.labels, self.args.device)
#      75 #print(embeds.shape)
# ---> 76 AUC, hits, ap = evaluate(embeds, self.split_edge)
#      77 return AUC, hits, ap
#
# File ~/Desktop/mGCN_Toolbox 0609/mGCN_Toolbox/model/DMGI/embedder_link.py:133, in evaluate(embeds, split_edges, isTest)
#     130 if eval > best_val:
#     131     best_val = eval
# --> 133     best_test, best_hits, best_ap = evaluate_model(log, embeds, split_edges['test']['edge'], split_edges['test']['edge_neg'],
#     134                                           None,
#     135                                           split_edges['test']['label'], test=True)
#     136     print('Epoch:', epoch)
#     137     print("Best Validation:", best_val)
#
# File ~/Desktop/mGCN_Toolbox 0609/mGCN_Toolbox/model/DMGI/embedder_link.py:68, in evaluate_model(model, embeds, edge, edge_neg, common_neighbors, labels, test, num_pos)
#      66 model.eval()
#      67 logits = model(embeds, edge, edge_neg)
# ---> 68 return evaluate_metrics(labels.cpu().numpy(), torch.sigmoid(logits).cpu().detach().numpy(), test, edge.shape[0])
#
# File ~/Desktop/mGCN_Toolbox 0609/mGCN_Toolbox/model/DMGI/embedder_link.py:57, in evaluate_metrics(true, pred, test, positive_num)
#      55 AUC_value = roc_auc_score(true, pred)
#      56 if test:
# ---> 57     hits = eval_hits(pred[0:positive_num], pred[positive_num:], 'numpy')
#      58     pred = torch.FloatTensor(pred)
#      59     true = torch.FloatTensor(true)
#
# File ~/Desktop/mGCN_Toolbox 0609/mGCN_Toolbox/model/DMGI/embedder_link.py:47, in eval_hits(y_pred_pos, y_pred_neg, type_info)
#      43     hitsK = float(torch.sum(y_pred_pos > kth_score_in_negative_edges).cpu()) / len(y_pred_pos)
#      45 # type_info is numpy
#      46 else:
# ---> 47     kth_score_in_negative_edges = np.sort(y_pred_neg)[-K]
#      48     hitsK = float(np.sum(y_pred_pos > kth_score_in_negative_edges)) / len(y_pred_pos)
#      49 hits_arr.append(hitsK)
#
# File <__array_function__ internals>:180, in sort(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1004, in sort(a, axis, kind, order)
#    1002 else:
#    1003     a = asanyarray(a).copy(order="K")
# -> 1004 a.sort(axis=axis, kind=kind, order=order)
#    1005 return a
#
# KeyboardInterrupt:
